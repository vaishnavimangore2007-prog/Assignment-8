# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavimangore2007-prog/Assignment-8/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dictionary
a={22:"ankita",28:"vaishnavi",40:"pallavi",41:"pratiksha",42:"sakshi"}
print(a)

#membership operation
print("vaishnavi" in a)

b={37:"dhanashri",39:"prachi"}
print(b)

#merge two dictionaries
merge= a|b
print(merge)

#converting dictionary into tuple
print(tuple(a))

c=print(list(a))
# Out:
#   File "/tmp/ipykernel_22179/2979002541.py", line 20
#     largest=max number
#                 ^
# SyntaxError: invalid syntax
